# %% [markdown]
# # Quickstart Notebook — Python Avanzado
# Comprobamos lectura de datos, filtrado y gráficos rápidos.

# %%
import pandas as pd
import numpy as np

pd.__version__, np.__version__
# Out:
# ('2.3.1', '2.3.1')

# %%
# Importar librerías
import pandas as pd

# Leer dataset
df = pd.read_csv("../datasets/ventas.csv")
df.select_dtypes(include='number').abs()


# df.head()
# Out:
#    cantidad  precio
# 0        10     5.2
# 1         4     7.1
# 2         6     5.0
# 3         9     3.9
# 4         7     7.2
# 5         2     4.1
