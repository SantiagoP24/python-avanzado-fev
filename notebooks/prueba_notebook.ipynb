# %% [markdown]
# # 🚀 Prueba de Notebook en Codespaces
#
# Este es un pequeño test para comprobar que VS Code detecta correctamente los notebooks `.ipynb`.
#
# A continuación ejecuta la siguiente celda de código 👇

# %%
print('✅ ¡Notebook funcionando correctamente!')
# Out:
# ✅ ¡Notebook funcionando correctamente!
